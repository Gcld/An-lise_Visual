# %% [markdown]
# <a href="https://colab.research.google.com/github/Gcld/Analise_Visual/blob/main/Projeto_1a_Gabriel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bibliotecas

# %%
# utilizar os Dataframes do Pandas para manipular as instâncias
import pandas as pd
# matplotlib para visualizar
import matplotlib.pyplot as plt
# gdown para baixar os dados
import gdown
plt.style.use('ggplot')

# %%
df = pd.read_csv('/content/Video_Games.csv')
df.head()
# Out:
#    index                      Name Platform  Year_of_Release         Genre  \
# 0      0                Wii Sports      Wii           2006.0        Sports
# 1      1         Super Mario Bros.      NES           1985.0      Platform
# 2      2            Mario Kart Wii      Wii           2008.0        Racing
# 3      3         Wii Sports Resort      Wii           2009.0        Sports
# 4      4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.68     12.76      3.79         3.29         35.52
# 3  Nintendo     15.61     10.93      3.28         2.95         32.77
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
#
#    Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# #Separando em um novo DataFrame com os elementos desejados

# %%
gData = df.loc[: , ['Name', 'Critic_Score', 'User_Score', 'Year_of_Release']]
gData.head()
# Out:
#                        Name  Critic_Score User_Score  Year_of_Release
# 0                Wii Sports          76.0          8           2006.0
# 1         Super Mario Bros.           NaN        NaN           1985.0
# 2            Mario Kart Wii          82.0        8.3           2008.0
# 3         Wii Sports Resort          80.0          8           2009.0
# 4  Pokemon Red/Pokemon Blue           NaN        NaN           1996.0

# %%
gData.info()
gData.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16928 entries, 0 to 16927
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16926 non-null  object
#  1   Platform         16928 non-null  object
#  2   Genre            16926 non-null  object
#  3   Publisher        16873 non-null  object
#  4   Year_of_Release  16655 non-null  float64
#  5   Global_Sales     16928 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 793.6+ KB
#        Year_of_Release  Global_Sales
# count      16655.00000  16928.000000
# mean        2006.48532      0.539520
# std            5.88289      1.550545
# min         1980.00000      0.010000
# 25%         2003.00000      0.060000
# 50%         2007.00000      0.170000
# 75%         2010.00000      0.490000
# max         2020.00000     82.530000

# %%
len(gData['Name'].unique())
# Out:
# 11563

# %%
len(gData['Critic_Score'].unique())
# Out:
# 83

# %%
len(gData['User_Score'].unique())
# Out:
# 97

# %%
len(gData['Year_of_Release'].unique())
# Out:
# 40

# %%
len(gData['Year_of_Release'].unique())
gData['Year_of_Release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
len(gData['Global_Sales'].unique())
# Out:
# 629

# %% [markdown]
# # Quantidade de jogos feitos pelas publicadoras

# %%
gData['Publisher'].value_counts().head(30)
# Out:
# Publisher
# Electronic Arts                           1389
# Activision                                1003
# Namco Bandai Games                         952
# Ubisoft                                    948
# Konami Digital Entertainment               839
# THQ                                        722
# Nintendo                                   721
# Sony Computer Entertainment                701
# Sega                                       647
# Take-Two Interactive                       427
# Capcom                                     392
# Atari                                      372
# Tecmo Koei                                 352
# Square Enix                                238
# Warner Bros. Interactive Entertainment     237
# Disney Interactive Studios                 224
# Eidos Interactive                          203
# Unknown                                    201
# Midway Games                               199
# Microsoft Game Studios                     193
# ...

# %% [markdown]
# # Novo DataFrame em relação a publicadora Nintendo durante a Sexta Geração dos Jogos Digitais (1998-2013)

# %%
nin = gData[(gData['Publisher'] == 'Nintendo') & (gData['Year_of_Release'] >= 1998.0) & (gData['Year_of_Release'] <= 2013.0)]
nin.head()
# Out:
#                     Name Platform     Genre Publisher  Year_of_Release  \
# 0             Wii Sports      Wii    Sports  Nintendo           2006.0
# 2         Mario Kart Wii      Wii    Racing  Nintendo           2008.0
# 3      Wii Sports Resort      Wii    Sports  Nintendo           2009.0
# 6  New Super Mario Bros.       DS  Platform  Nintendo           2006.0
# 7               Wii Play      Wii      Misc  Nintendo           2006.0
#
#    Global_Sales
# 0         82.53
# 2         35.52
# 3         32.77
# 6         29.80
# 7         28.92

# %%
nin.info()
nin.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511 entries, 0 to 16922
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             511 non-null    object
#  1   Platform         511 non-null    object
#  2   Genre            511 non-null    object
#  3   Publisher        511 non-null    object
#  4   Year_of_Release  511 non-null    float64
#  5   Global_Sales     511 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 27.9+ KB
#        Year_of_Release  Global_Sales
# count       511.000000    511.000000
# mean       2005.843444      2.424325
# std           4.023333      5.739147
# min        1998.000000      0.010000
# 25%        2003.000000      0.270000
# 50%        2006.000000      0.730000
# 75%        2009.000000      2.085000
# max        2013.000000     82.530000

# %%
nin['Platform'].unique()
# Out:
# array(['Wii', 'DS', 'GB', 'GBA', '3DS', 'N64', 'GC', 'WiiU', 'SNES'],
#       dtype=object)

# %% [markdown]
# # Novo DataFrame em relação aos jogos de GameBoy

# %%
gb = nin[(nin['Platform'] == 'GB')]
gb.shape
# Out:
# (21, 6)

# %%
gb.head(21)
# Out:
#                                           Name Platform         Genre  \
# 12                 Pokemon Gold/Pokemon Silver       GB  Role-Playing
# 30     Pokémon Yellow: Special Pikachu Edition       GB  Role-Playing
# 133                    Pokémon Crystal Version       GB  Role-Playing
# 174                            Pokemon Pinball       GB          Misc
# 201                          Super Mario Bros.       GB      Platform
# 339                  Pokémon Trading Card Game       GB      Strategy
# 731   The Legend of Zelda: Link's Awakening DX       GB     Adventure
# 741                               Wario Land 3       GB      Platform
# 748                        Donkey Kong Country       GB      Platform
# 896                                  Tetris DX       GB        Puzzle
# 897        The Legend of Zelda: Oracle of Ages       GB        Action
# 929     The Legend of Zelda: Oracle of Seasons       GB     Adventure
# ...
